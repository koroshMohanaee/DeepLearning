# %% [markdown]
# <a href="https://colab.research.google.com/github/koroshMohanaee/DeepLearning/blob/main/diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!wget https://github.com/koroshMohanaee/DeepLearning/tree/main/Keras%26Tensorflow/dataset/dataset.py
# !wget https://github.com/koroshMohanaee/DeepLearning/tree/main/Keras%26Tensorflow/dataset/diabetes.csv -P dataset
# Out:
# --2024-10-16 07:12:39--  https://github.com/koroshMohanaee/DeepLearning/tree/main/Keras%26Tensorflow/dataset/diabetes.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/koroshMohanaee/DeepLearning/blob/main/Keras%26Tensorflow/dataset/diabetes.csv [following]
# --2024-10-16 07:12:39--  https://github.com/koroshMohanaee/DeepLearning/blob/main/Keras%26Tensorflow/dataset/diabetes.csv
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dataset/diabetes.csv’
#
# diabetes.csv            [ <=>                ] 208.40K  --.-KB/s    in 0.05s
#
# 2024-10-16 07:12:40 (4.05 MB/s) - ‘dataset/diabetes.csv’ saved [213402]

# %% [markdown]
# ## import libererry

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %% [markdown]
# ## load data

# %%
from google.colab import files
uploaded = files.upload()
df=pd.read_csv('/content/diabetes.csv')
# Out:
#      <input type="file" id="files-a167b5f0-e4c4-4957-8940-d24e238eb593" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a167b5f0-e4c4-4957-8940-d24e238eb593">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## data cleaning

# %%
df.dropna()
df.dropna(axis=1)
#df["Glucose"].fillna(df["Glucose"].mean(),inplace=True)
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## Variables Encoding

# %%
#one hot encode
df = pd.get_dummies(df, drop_first=True)
#--------------------------------------------------
# move y column to last coloumn
column_to_move = df.pop("Outcome")
df.insert(len(df.columns), "Outcome", column_to_move)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## Splitting the dataset

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state =0)
